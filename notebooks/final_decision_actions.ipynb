# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\CUIDAIHACK\output\final_decision_actions.csv")

action_counts = df["recommended_action"].value_counts()

plt.figure()
plt.barh(action_counts.index, action_counts.values)
plt.xlabel("Count")
plt.ylabel("Action Type")
plt.title("Recommended Operational Actions")
plt.tight_layout()
plt.show()
